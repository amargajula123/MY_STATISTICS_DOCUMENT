# %%
Agenda:=

1. Anova test or (F-test)
2. EDA -->{solve some examples}

Note iq :=
    when i use "F_test" and "T_test" or "Z_test" ?
    
why do use anova test ?
        
        per suppose i have 5 cricket  players be i wanted 
        to no the mean of two or more groups here basically
        happening 

       ex := whether "a" and "b" will performing well some ex project
        so which test you going to choose 
        
        ANS : only 2 groups are there so we use T_test 
            or Z_test 

1 .what is Anova test :=
        this is "inferetial statistics". "anova" basically
        means "Analysis of variance" .
        
        Anova is a "statistical method" used to compare 
        the "Means" of 2 or more groups      
    
    
    in anova 2 things are IMP 
    
        1. Factors    2. Lebels
        (variables)
        

        
Ex := we have medicine this madicine has different
      different doses like  
      dosage           dosage           dosage
       0mg             50mg             100mg
        9                7                4 
        8                6                3
        7                6                2
        8                7                3
        8                8                7
        
"Factores" := here "factor"  is nothing but it can be dosage.
           factor also called as  "variables"
    
"Lelevs" :=leves are 0mg 50mg 100mg level basically means
             "sub cotegiries"
        
     levels can be many no.of levels   
         
    one more example Gender :=   Gender   
                                    |
                             |-----------------| 
                          female              male
                    
    NOte := male & female are 2 "levels" & Gender can be a 
            "Factore"
            
                 
Different types of "Anova"  
1. One way Anova
2. Repeated measure Anova
3. Factorial  Anova

   1. One way Anova :=
        it bassically says "one factor" with atleast "2 levels"
        leves are "independent".
        
          EX: upper madicine have 1 factore "dosage" have different
              levels like 0mg 50mg 150mg 
        
   2. Repeated measure Anova :=
         you have only "1 factore" with atleast "2 levels" but
         levels are "dependent"
            
            Ex := running km in day1  day2 day3  day4
                                 6     4    2      8
                     so here ecah day having some dependency 
                    of previous days 
                    
                factor
                level
                
                
   3. Factorial  Anova :=
           Two are more "factores" each of wich with
        atleast "2 levels". levels can be either "independet" 
        are "dependent" or both
        
          its combination of 1. "One way Anova"
                             2. "Repeated measure Anova"
            
        
Ex factore like
        ----------------------------------------
        |        |  day1   |    day2  |  day3  |
        |        |    9    |     7    |   5    |
        |  men   |    8    |     6    |   3    | 
        |--------|---------|----------|--------|  
        | women  |    8    |    7     |   4    |
        |        |    9    |    8     |   6    |
        |        |         |          |        |
        ----------------------------------------
        
One way Anove (F-test) --> Inferential Stats
                             |
                             |--->comparing "means"
                                  of 2 or more groups
            
{IQ}
    Researchers want to test a new anxity medication. they 
    split participants into 3 conditions (0mg,50mg.100mg)
    then ask them to rate their anxity level on scale of
    1-10. are there any defferences B/w the 3 condition  
    using α = 0.05
    
        0mg       50mg      100mg
         9          7         4
         8          6         3
         7          6         2
         8          7         3
         8          8         4
         9          7         3
         8          6         2
            
            here i come too know its having "1 factore"(mg) & with 
            atleats "2 levels" and levels are independet so its a
            'ONE WAY ANOVA'
            
Step :1
    
Null hypothesis     : H0 = µ(0mg) = µ(50mg) = µ(100mg)
Alternat hypothesis : H1 = not all "µ" means are equal
                           " 2 tail test "
    
step :3
    Sate the Alpha "α" and "confidence_interwell" C.I = 1-α = 1-0.05=0.95 
    
    "Significance value" ("α") =  0.05   and C.I = 95%
    
step :4
    in "F_test" also we calculate "degree of freedom"
    but here we calculate "3 type" of "degree of freedoms"
    
   F_tavle answer is come with the help of degree of freedoms
    here we need to calculate 3 types of Degree of freedom
           
       1, Degree of freedom B/W    (a-1)
       2, Degree of freedom Within (N-a)
       3, Degree of freedom Total  (N-1)
       
    
    "Population_{N}"                       "sample_{n}"
here if i combine all the               here if i combine
data points that will my                each cotegeri has 7
population size--> N=21                  --->  n=7
            
          [:.  how many no.level = a]
                  a = 3
            
                                
    df Between = a - 1 = 3 - 1  = 2

    df within  = N - a = 21 - 3 = 18
    
    df total   = N - 1 = 21 - 1 = 20
    
    what do we have to do with degree of freedom ?
    
step : 4
    
    State dcision rule 
    
    here we use 
                Degree of freedom B/W     (a-1)
                Degree of freedom Within  (N-a)
            
            = > (2,18) = range
    
    df Between = a - 1 = 3 - 1 = 2   here we getting range
                                      of (2,18)   
    df within  = N - a = 21 - 3 = 18   3.5546
    
    (2,18) after knowing the range see F-table the value will
    be 3.5546
    
    
    
    
    
    
    
    
    
      ----|-------------------------|----
        -3.5546                   3.5546
        
    If "F test" value is greater then 3.5546 we " reject the null hypothesis"
    if "F test" is less then -3.5546 reject the "Null hypethesis".
    
    
Calculae the F-test Statistics :=
-------------------------------------------------------------   
       |Someofsqre | degrreofreedom |  meansqre |   F-value  |
-------|-----------|----------------|-----------|------------|     
Between|  98.66    |      2         |   49.33   |    86.543  |
       |           |                |           |            |
       |-----------|----------------|-----------|------------|
       |           |                |           |            |
Within |  10.28    |      18        |    0.57   |            |
       |           |                |           |            |
-------|-----------|----------------|-----------|------------|
       |           |                |           |            |
Total  | 108.94    |       20       |   49.90   |            |
-------------------------------------------------------------|

                           Someofsqre        98.66 
"meanSquare" will find = ---------------- = ------- = 49.33
                          degrreofreedom       2
    
                             similarly  10.28/18    =  0.57
    
        total =>   49.33 + 0.57 = 49.90
        
        f_valu =>  49.33 / 0.57 = 86.543 "ans" 
    
    
 1.first formula := Some_of "square_bitween"
-------------------------------------------

              ∑ (∑ai)²     T²
Ss between = --------- -  --- 
                 n         N  
    about formula :=
        ai --> a(i) is nothing but bassically says that
               each and every value that you see in data
               set 3 levels do that sametion 
                
               T is nothing but sum of all the values that we
               are getting and whole square
        

(∑ai)²  = (9+8+7+8+8+9+8)²+(7+6+6+7+8+7+6)²+(4+3+2+3+4+3+2)²

        = 57²+47²+21²
        
        T² = [57+47+21]² =(125)² = 15,625 
        
              57²+47²+21²     (125)² 
Ss between = ------------  -  ------ = 842.71-744.04 = 98.66
                   7            21
    
 2.second formula := Some_of "square_within"
--------------------------------------------- 

                     ∑ (∑ai)²    
Ss within = ∑ Y² -  ---------  
                        n        
   
 ∑ Y² = 9²+8²+7²+8²+8²+9²+8²+7²+6²+6²+7²+8²+7²+6²+4²+3²+2²+3²+4²+3²+2² = 853
      = 853
        
                     57²+47²+21²     
Ss within = 853 -   ------------ = 10.28
                         7  
    
@last final "F_test" is :=
    
     
                  MsBetween     49.34
Finally F-test =  ---------- = -------- = 86.543
                  Mswithin       0.57
    
Final conclusion :=
    86.543 > 3.5546 so we reject the Null hypothesis
    
    If 86.543 test is greater then 3.5546 reject the 
    "null hypothesis"    
    
   Ans : reject the null hypothesis
# Out:
#   File "<tokenize>", line 10
#     in anova 2 things are IMP
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
49.33/0.57
# Out:
# 86.54385964912281

# %%
108.94571428571433/20
# Out:
# 5.447285714285717

# %%
98.66+10.285714285714334
# Out:
# 108.94571428571433

# %%
              57²+47²+21²     (125)² 
Ss between = ------------  -  ------ = 842.71-744.04= 98.66
                   7            21

# %%
853-(((57**2)+(47**2)+(21**2 ))/7)#-(((125)**2)/21)
# Out:
# 10.285714285714334
