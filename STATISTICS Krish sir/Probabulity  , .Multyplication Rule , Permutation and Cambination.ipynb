# %%
Probabulity :=
    Probabulity is a measure of the likelihood of an event
    
    Ex := roll a dice {1,2,3,4,5,6}
        
                    no.of wqy an event can occure       1
        P_r (6)  = -------------------------------  = ------
                       no.of possible outcome            6
            
            
                toss a coin  { Head , Tail}
                                                1
                probabulity of getting tail = ------ 
                                                 2 
                    
super IMP 
$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
1. Additional Rule ("Probabulity" , "or")
#########################################

  *Mutual Exclusive Events :=
        
        2 events are mutual exclusive if they can not 
        occure at the same time
        
      Ex :=
        Rlling a Dise {1,2,3,4,5,6} You`ll only get one 
        number this is mutual exchangive event
        
      Ex := Tossing a coin you`ll not get 2 side 
            only one side is avail  
            
  *Non Mutual Exclusive Events := 
       
        Multiple events can occur at the same time
        
       Ex := Deck of cards  lets consider when i pull
             out cards {Q card , K card , Hearts  card}
            
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
  
    @_Mutual Exclusive Events Examples
    
    
{Q} if i toss a coin ,what is the Probabulity of the coin
   landing  on heads on tail  ?
      Ans :=
            it is Mutual Exclusive Events
            
    what is the probabulity  of getting head or tails
                                  1      1
    P_r(A or B) = P(a) + P(b) = ----  + ---
                                  2       2 
    P_r(A or B) = 1
    
    whenever we have mutual Exclusive Events and that poin 
    of time you can define P_r(A or B) = P(a) + P(b)
    this definition Which is also called as "addition rule"
            
{Q} what is the probabulity if i am role a dise ?
                                              1     1      1      3        1 
     Pr(1 or 3 or 6 ) = Pr(1)+Pr(2)+Pr(3) = ---- + ---  + ---- = ---- =  ---- = 0.5
                                              6     6       6      6       2 
            
    @_Non Mutual Exclusive Event Examples
    
    := your are picking a card  randomly from a deck =:
         
  {Q} what is the Probabulity of choosing a card that is
      Queen or a Heart ?
        Ans :=
            it is Non Mutual Exclusive Events
                      4                        13
    Pr(Queen_card) = ---- ,  Pr(heart_card) = -----  
                      52                        52
                                        1   
        how many Pr(Queen and Heart) = ---- 
                                        52      
            
        Addition rule for Non Mutual Exclusive  Event
        
        Pr(A or B) = P(A) + P(B) - P(A and B)
        
        What is the Probability of getting Queen or Heart
        
        P(Queen or Heart) = P(Queen) + P(Heart) - P(Queen and Heart)
        
        
        
                                        4      13     1     16
        how many Pr(Queen or Heart) = ---- + ---- - ---- = -----  = 0.3076 
                                        52     52    52     52
            
$$$$$$$$$$$$$$$$$$$$$$$$            
2.Multyplication Rule :=
######################## 
    
      1.Indipendent Events
      2.Non Indipendent Events  
    
  1.Indipendent Events  :=
    in the case of Indipendent event 
      Ex : rolling a Dise {1,2,3,4,5,6}
            
            1 event is not dependent on the Other Event.
            Each and every event are indipendet this is
            Independent event
            
  2.Non Indipendent Events or Dependent Events :=
    
       Ex : I have bag inside that 3 
            red murbles 2 green murble
            
            if i pick out the murble what is the Probabulity of
            "red" murble    
                                    3   
                 Pr (red_murble) = -----
                                    5 
            in 1st instent  u picked 1 red murble
            after remaing 2 there  
                
            now 2 red marble 2 green murble
            
            if i pick out the murble what is the Probabulity of
            "green" murble
                                       2 
                  Pr (green_murble) = ---- it has impacted B-coz Marble is reduce 
                                       4
                this is a Dependent or Non Indipendent Event dsays
                
            there is amezing Algorithem called
              * NAIVE BAYES {Conditional probabulity}
                
Problem Statement :
    Indipendent_Event :
        {Q} what is the probability of rooling a "5" and
            then a "4" in a Dise ?
            
          Ans :=
               it is Indipendent Event
                
                apply the multyplication rule
                
                Pr(A and B) = P(A)*P(B)
                
                              1     1     1
                Pr(5 and 4) =--- + --- = ---- 
                              6     6     36  
    Dependent_Event :
        {Q} what is the probability of drewing a Queen and
            then a  Aces from a deck of card ?
            
          Ans :=
               it is Dependent Event
                
            Pr(A and B) = P(A)*P(B/A) 
            
            :. B/A is called as conditional probability
                
            Ex := I have bag inside that 3 
                  red murbles 2 green murble 
                    
                    in 1st instence what is Probabilityos 
                    Green & red 
                                                       3
            i pick out 1 green marble so Pr(green) = -----
                                                        5             
                                                        
                                                         2   
and the pick out 1 another red marble so now Pr(red) = ----
                                                         4
                
                                        3               
                    P(Green and red) = -----
                                         5 
                    
                    so similarly Qween and Aces
                    
                    Pr(Qween and Aces) = P(Qween)*P(Aces/Qween)
                    
                                          4        4  
                                       = ----- * ----- = 0.1553
                                          52       51 
                    
                    
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%                
Permutation and Cambination :=                
    
    Permutation :=
        
        i have taken some student for school trip and we went
        to {choclate factary}
        
        Student {Assignment} --> write the 1st 3 choclates
                                 which ever you see in your
                                 dairy.
                now in 1st instance how many defferent option
                this particuler student can have of seeing the 
                chocolate 
                
                6 is there in 1st instance 1 was pickup
                remain 5 in 2nd  --- 4 remain 
                
                6 * 5 * 4 = 120 
                
                120it is the all possible permutations W r t 
                Chocolate name that he may see this is called permutation
                
        
        manifacture ->{Dairy,5-ster,milkybar,Silk,kitkat,Blackforest}
        
        Permutation fomula :=
            
                     n!          n = 6 ,r = 3 
            nPr = -------
                   (n-r)! 
                                                     3!
                                               note: --- = 1
                                                      3! 
                      6!      6*5*4*3!
             nPr = ------  = ---------- =  120
                    (6-3)!       3!
            
Difference B/W permutation and Combination :=
    
    
Combination :=
    now here {dairy  , germs , kitkat} if i use this element
                                       this combination i cannot
                                       use  this same element so
                                       combination will be uniqe 
                                       w r t elements that is used
                    
                    
                       n!        6!         6*5*4*3!
             nCr = --------- = --------  = ---------- =  20 unique combinations
                    r!(n-r)!   3!(6-3)!     3*2*1*3!
