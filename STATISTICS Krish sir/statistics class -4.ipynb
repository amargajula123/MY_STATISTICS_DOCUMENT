# %%
Agenda :=

1.Covariance
2.Pearson Correlation Coefficent
3.Spearman Rank correlation Coefficent
4.Chi_square test {"categorical"}
5.Anova test or F_test


**Covariance :=
    
    
 X                   y 
-----               ------
weight              height 
50                   160cm
60                   170cm
70                   180cm
75                   181cm

if i want to  quantifying(లెక్కించడం) the relationship B/W 'X' and 'Y' 
means nothing but 
    
    like "X" is increasing "Y" is increasing 
         "X" is increasing "Y" is decreasing
         "X" is decreasing "Y" is increasing
         "X" is decreasing "Y" is decreasing
        
        if my dataset values looks like this.
        
       Y 
        ^  
        |           * *
        |     *  *
  {g}   |    * *   *
        |  *  *
        |  * *            
        |--------------->X
here "X" is increasing "Y" is increasing
here "X" is decreasing "Y" is decreasing

       Y 
        ^  
        |  * *
        |    *  *
  {g}   |    * *   
        |      *  *
        |           * *            
        |--------------->X
        
here "X" is increasing "Y" is decreasing 
here "X" is decreasing "Y" is increasing 



we the relationship so after seeing X & Y axis we need to provide
some value to it when we are able to provide value to it that basically
means we are able to Quantified(లెక్కించడం) that relation ship
   
 @Covariance_Formula :=
        
        population Covariance_Formula
        
                     N   (Xi - x̄)(Yi - ȳ)
         Cov( x,y) = ∑ --------------------
                    i=1      N - 1
            
        sample Covariance_Formula
        
                     n   (Xi - x̄)(Yi - ȳ)
         Cov( x,y) = ∑ --------------------
                    i=1      n - 1
            
        Note :   x̄ means "mean" of "X"   ȳ means mean of "Y"
            
Note : "Variance"(x) is nothing but "Covariance" of (x,x).
    

@Variance formula
            
              n    (xi-x̄)²          n   (x-x̄)*(x-x̄)
    Var(x) =  ∑  ----------   ==>   ∑ -------------   
             i=1    n-1            i=1      n-1
        
        
                       n (x-x̄)*(x-x̄) 
            Cov(x,x) = ∑  -----------
                      i=1     n-1
                
                
                
                here  "degree of freedom "= n-1 
                
"Covariance" it is basically talk about "2 variable" x,y 
whether that "positively" increasing or "nagatively" increasing    
                
    we will get either +ve -ve or either 0
    
    what actually the +ve coralation:=
        
        this is nothing but +ve correlation or coveriance
        
       "x" is increasing "y" is increasing
       "x" is decreasing "y" is decreasing
        
    what does the -ve  coralation:= 
        
        this is nothing but -ve correlation or coveriance   
       "x" is decreasing "y" is increasing
       "x" is increasing "y" is decreasing

    
    
population varianve fromula            sample var formula 

      N   (xi-µ)²                        n   (xi-x̄)²
σ² =  ∑   ------                   s² =  ∑   ------
     i=1     N                          i=1    n-1   
    
    
               n   (xi-x̄)²
    Cov(x,x) = ∑ ---------- 
              i=1   n - 1 
        
                n  (xi-x̄)²     n  (xi-x̄)*(xi-x̄) 
        Var_x = ∑ --------- =  ∑ --------------
               i=1  n - 1     i=1     n-1
            
            
                   n  (xi-x̄)*(xi-x̄) 
        Cov(x,x) = ∑ --------------
                  i=1     n - 1 
            
            Ex : X          Y
                 2          3 
                 4          5
                 6          7
              ----------------      
                x̄=12/3     ȳ= 15/3
                
                x̄ = 4   ȳ = 5 insert this values into Covariance
                
                
                     n   (Xi - x̄)(Yi - ȳ)
          Cov(x,y) = ∑ --------------------
                    i=1       n - 1
            
                  n  (2-4)(3-5)+(4-4)(5-5)+(6-4)(7-5) 
        Cov_x,y = ∑ ----------------------------------
                 i=1              2
            
            x having 3 element 
            y havint 3 elements data so "n" = 3 3-1 = 2
            
                  n  (-2)(-2)+0+(2)(2)      8
        Cov_x,y = ∑ -------------------- = --- = 4
                 i=1          2             2

when we get "+Ve value" means "+Ve Corelation" means "X" increasing "Y" increasing
or  "X" decresing "Y" decreasing.

when we get "-Ve value" means "-Ve Corelation" means "X" increasing "Y" decreasing
or  "X" decresing "Y" increasing.


Disadantage of "Coveriance" :=  
    
if i am getting some value with the help of "Covariance"(x,y) we will either 
get a "possitive" or "nagetive" value, when ever we get a "+ve" or "-ve" value
ther is no limit, means for some of the features imay get +500 for some of the
fetures i my get -400,like -200,1000 so there is "no limit how much possitivly"
or "how much negatively corelated", so it may be "infinity" this is the megor
"Disadvantage",
    
our main Aim is we should try to "Restric" the "Covariance" with respect
to "Correlation" we should try to "Restric" it with some specific value 
like [ -1 to 1] this is been done by another "Correlation" called
"Pearson Correlation Coefficent".
            
            
    what about this "condition"   :
    
         "X" is increasing "Y" is decreasing
         "X" is decreasing "Y" is increasing
            
           
    
            
@Pearson_Correlation_Coefficent :=
    
    The more towords +1 more positively correlation
    The more towords -1 more negatively correlated
    [:. ρ = row sign]
    
    
             Cov[x,y]
    ρ x,y = ------------  B-coz of this ["σx  σy"] it will 
              σx   σy     try to get "restricted" B/w ["-1 to 1"]
                          The more the value towords 1 more 
                          "+ve" it is 'Correlated'
                
why this is used  ?

  lets say               
       i have Data_set like = 1000 Features
    do you feel you will be use all the 1000 feature in "ML"
    if we use like that "corrrese dimentionality reduction" will
    be increasing
    
    ANS := no 
    
@features like    X Y Z A B C   o/p 
    
out all this features which feature i actually use?
    
which will actually help me to predict my output feature,that feature 
you can use, So here "output feature" is my "Dependent_feature".
dependent feature is nothing but my final output i need to find this
by using "independet features",
    
    So x y z a b c "Independent Features"
    
  

Disadvantage of "Pearson_Correlation_Coefficent"
                
@Spearman_Rank_Corelation :=
   
    in Spearman Rank Corelation we bassically createts "Rank"

according to 'Spearmans rank correlation' we are able to get 
1. but "Pearson Correlation" when we find out that value
its  0.88


"Spearman_Rank_Corelation" we basically find out "rank"

          Cov(R(x),R(y))
    rs = -----------------
          σR(x)   σR(y)
        
                            choose the rank of x ,y  here
            
                              x     y    Rx   Ry
                              1     2     4    4
                              3     4     3    3
                              7     5     2    2
                              0     7     5    1
                              8     1     1    5
                             ----------    
                        skip this part
                        
                        
Sraite line "pearson correlation" will work
  Y
  |   /
  |  /
  | /
  |/
  |----------> X

Disadvantage of "Pearson_Correlation_Coefficent"

if the data is  non linear / non Sraite line even though it has +ve or -ve 
corellation it will not able to capture that specifice information
we get "lesser value" then 1

  Y        /
  |       *
  |      /
  | ..-*
  |/ 
  |----------> X

Why do you use 'Spearman Rank Corelation':=
    it captures the" Non linear" Properties very clearly that means 
    our value will be 1

# %%
1.5/2.317098
# Out:
# 0.647361484063255

# %%
0.8981*2.58
# Out:
# 2.317098

# %% [markdown]
# # Chi_Square_test

# %%
IMP := test                 
    $$$$$$$$$$$$$$$          
    Chi_Square_test :=
    $$$$$$$$$$$$$$$    
        
The "Chi_Square_test" claims about "Populations" and "Propotions". it is
a "Non Porametric test" that is performed on "Cotegorical variable"(nominal)
(or ordinal) data. 

The test is applied when you have "two categorical variables"  from a 
single population. It is used to determine whether there is a significant
association between the two variables.
        
    {IQ} in the 2000 indian censes the ages of indivisuals 
         in small town were found to be the following
        
    
   |--------------------------------|
   |  <18    |   18-35     |   >35  |   
   |---------|-------------|--------|
   |   20%   |    30%      |   50%  |               
   |--------------------------------|    
    
    
    In 2010 , ages of  n=500 individuals were sample
    below are the results
    
    
   |--------------------------------|
   |  <18    |   18-35     |   >35  |   
   |---------|-------------|--------|
   |   121   |    288      |   91   |               
   |--------------------------------|

    using "Significance_Value"( α )= 0.05 would you conclude
    the "population distribution" of ages has changed in the
    last 10 years?
    
                  ---------------------------------
 Ans :=           |  <18   |    18-35    |    >35 |
                  |--------|-------------|--------|   
    expected      |  20%   |    30%      |   50%  |
                  ---------------------------------
        
        if you need "expected values" so multyply
        sample n=500 with percentage values and divide it by 100
        
                  ---------------------------------
                  |  <18   |    18-35    |    >35 |  500*0.20 = 100.0
                  |--------|-------------|--------|  500*0.30 = 150.0
    obsered values|   121  |     288     |   91   |  500*0.50 = 250.0
     n=500        ---------------------------------
  Expected values |  100   |     150     |   250  |
                  ---------------------------------
    
so here  α = 0.05  so "confidence interwell" C.I = 95%
    
    
    1. H0 = the data meets the expected distribution 2000 census
    2. H1 = the data not meets the expected distribution 2000 census
    
2.step :=
State the alpha "Significance Value"(α)=0.05 = 1- α = 1-0.05 so C.I = 95%
    
3.step :=
    Calculate the degree of fredom

        df = n-1 = 3-1 = 2   --> rejon we have 3 "Cotegeris"
        
        when ever you have "columns" and "rows" data so you can use 
        "degree of freedom" formula is
        
        ==> (n-1)*(m-1) "n"is no.of rows "m"no .of columns
        
        (2-1)*(3-1)= 1*2 = 2
        when your given queqion is not in % persentage use (n-1)(m-1) DOF
        
        after geting DOF = 2 and α = 0.05 values see in "chi_squre" 
        table my value will be 5.991
        
        
step 4 :=
    dission rule := X²  is "greater then" 5.991 then
                    reject the "Null hypothesis"
            
            
        now go and apply test statistics value    
step 5 :    
    
              (fo - fe)²      (obsered - expected)²
    X² =   ∑ ------------- = ----------------------
                 fe                expected
            
         (121 - 100)²      (288 - 150)²      (91 - 250)²
    ∑ ---------------- +  -------------- + -------------
            100               150              250
        
        
        441    19044     25281
        ---- + ------ + ------- = 4.41+126.96+101.124= 232.494
        100     150       250
        
         X² = 232.494 
            
    dission rule : 232.494  is greater then 5.991 then
           reject the Null hypothesis
            Ans : 'reject' the 'Null hyppothesis'
                
                
{IQ}
A school principal would like to know which days of the week students are 
most likely to be absent.the principal expects the students will be absent
equally during the 5 days school week, the principal select a random sample of
100 teachers asking them which day of the week they had the highest number of
student absent,

the observed and expected result are shown in the table below based on table
results, do the days for the highest number absents occured with equal 
freaquency use (95%) C.I


          monday     tuesday    wednessday   thusday    friday
observed   23           16         14           19          28
expected   20           20         20           20          20  



          monday  |   tuesday  |  wednessday |  thusday  |  friday |
observed   23     |      16    |     14      |     19    |    28   |
expected   20     |      20    |     20      |     20    |    20   |
         -----------------------------------------------------------
n=100      20            20          20            20         20
 
      n*exp = X
    100*0.20 = 20.0
    100*0.20 = 20.0
    100*0.20 = 20.0
    100*0.20 = 20.0
    100*0.20 = 20.0
    
step : 1
    
so here 'SV'  α = 0.05  so "confidence interwell" C.I = 95%

step : 3
    Calculate the degree of fredom
    
              df = n-1 = 5-1 = 4   --> regan we have 5 cotegeris
          after seeing 4 and α = 0.05 values in chi_squre 
        table my value will be 9.488
        
    we say this in praticaly in code this as critical_valu = 9.488
        
        when ever you have columns and row data so
        you can use "degree of freedom formula" is 
             and 
            when data in not in "persentage" we use this as
            degree of freedom
        
    ==>  (n-1)*(m-1) "n"is no.of rows "m"no .of columns
    
       (2-1 )*(5-1)=1*(4)=4
    
step 4 :=
    dission rule := X²  is greater then 9.488 then
                    reject the "Null hypothesis"
            
            now go and apply test statistics value  os chi-square  
        
step 5 :             (f0 - fe)²      (osered - expected)²
           X² =   ∑ ------------- = ----------------------
                        fe                expected
            
         (23 - 20)²       (16 - 20)²         (14 - 20)²     (19 - 20)²       (28 - 20)²
    ∑ ---------------- + -------------- +  ------------- +  ----------- +  ------------ 
            20                 20              20                20            20            
        
        
        9     16      36      1      64
       --- + ---- +  ----- + ---- + ----- = 0.45+0.8+1.8+0.05+3.2 = 6.3
        20    20      20      20     20  
        
        X² = 6.3
    dission rule : 6.3  is greater then 9.488 then
           reject the Null hypothesis
            
            Ans : 'Accept' the 'Null hyppothesis' 
                
                
  Statistics :=
    Data Analist , Data Scientist
    
    Analysis :  Dcriptive  Inferential
        
        
        for P_value : = 
            
            
            chi_square_statistic  = 0.001934

DOF = 1

see dof = 1 chi-square value = 0.001934 in chi table this 0.001934
ranging b/w 0.975	0.20 so here you the p_value

# %%
(280 - 150)
# Out:
# 130

# %%
4.41+126.96+101.124
# Out:
# 232.494

# %%
import seaborn as sns
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## findind correlation b/w total_bill & tips
#
#      if i want to see covarince  it always
#      work on "numerical values" only its not work
#      categorical values remember b-coz in formula we add values not strings

# %%
df.corr() # by defult "pearson correlation will applyed"
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# # finding the spearman correlation

# %%
df.corr(method='spearman')
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.678968  0.604791
# tip           0.678968  1.000000  0.468268
# size          0.604791  0.468268  1.000000

# %% [markdown]
# # finding the correlation of pearson

# %%
df.corr(method='pearson')
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.corr() # by defult pearson
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# # now finding Coveriance

# %%
df.cov()
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
l=sns.get_dataset_names()
len(l)
# Out:
# 19

# %%
sns.load_dataset("iris")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1=sns.load_dataset("iris")
df1.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
df1.corr(method="spearman")
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.166778      0.881898     0.834289
# sepal_width      -0.166778     1.000000     -0.309635    -0.289032
# petal_length      0.881898    -0.309635      1.000000     0.937667
# petal_width       0.834289    -0.289032      0.937667     1.000000

# %%
df1.corr(method="pearson") # by defult method="pearson" only
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
df1.cov()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006
